# %% [markdown]
# ### Building a Podcast Summarizer using GPT-3

# %%
import whisper
import pandas as pd
from pytube import YouTube
import openai
import numpy as np
import tiktoken

# %% [markdown]
# Checking for the different types of models, it is interesting to see the different sizes for the 'Whisper Models' provided by OpenAI - https://github.com/openai/whisper/blob/main/model-card.md
#
# ![image.png](attachment:image.png)
#
# Here their definition by OpenAI: The Whisper models are trained for speech recognition and translation tasks, capable of transcribing speech audio into the text in the language it is spoken (ASR) as well as translated into English (speech translation). Researchers at OpenAI developed the models to study the robustness of speech processing systems trained under large-scale weak supervision. There are 9 models of different sizes and capabilities, summarized in the following table.
#
# In this case we will utilize the 'base' model.

# %%
model = whisper.load_model('base')

# %% [markdown]
# ##### Retrieving Youtube's URL
# Here we will be using MKBHD's video for reference : https://www.youtube.com/watch?v=cneoANZKBGk

# %%
def retrieve_youtube_url():
    url = input('\nPlease enter your Youtube URL of choice and press enter\nTo exit, type "F" and press enter')
    print('\nHere your URL: ', url)
    return url
yt_url = retrieve_youtube_url()
youtube_video = YouTube(yt_url)
# Out:
# Here your URL:  https://www.youtube.com/watch?v=cneoANZKBGk

# %%
# Display all the relevant attributes/directories regarding the video
dir(youtube_video)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_age_restricted',
#  '_author',
#  '_embed_html',
#  '_fmt_streams',
#  '_initial_data',
#  '_js',
#  '_js_url',
#  '_metadata',
#  '_player_config_args',
#  '_publish_date',
#  '_title',
#  '_vid_info',
#  '_watch_html',
#  'age_restricted',
#  'allow_oauth_cache',
#  'author',
#  'bypass_age_gate',
#  'caption_tracks',
#  'captions',
#  'channel_id',
#  'channel_url',
#  'check_availability',
#  'description',
#  'embed_html',
#  'embed_url',
#  'fmt_streams',
#  'from_id',
#  'initial_data',
#  'js',
#  'js_url',
#  'keywords',
#  'length',
#  'metadata',
#  'publish_date',
#  'rating',
#  'register_on_complete_callback',
#  'register_on_progress_callback',
#  'stream_monostate',
#  'streaming_data',
#  'streams',
#  'thumbnail_url',
#  'title',
#  'use_oauth',
#  'vid_info',
#  'video_id',
#  'views',
#  'watch_html',
#  'watch_url']

# %%
# Obtaining only the audio
streams = youtube_video.streams.filter(only_audio=True)
streams
# Out:
# [<Stream: itag="139" mime_type="audio/mp4" abr="48kbps" acodec="mp4a.40.5" progressive="False" type="audio">, <Stream: itag="140" mime_type="audio/mp4" abr="128kbps" acodec="mp4a.40.2" progressive="False" type="audio">, <Stream: itag="249" mime_type="audio/webm" abr="50kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="250" mime_type="audio/webm" abr="70kbps" acodec="opus" progressive="False" type="audio">, <Stream: itag="251" mime_type="audio/webm" abr="160kbps" acodec="opus" progressive="False" type="audio">]

# %%
# Downloading audio into directory
stream = streams.first()
stream.download(filename='audios.mp4')
# Out:
# 'c:\\Users\\ismae\\Personal-Projects\\Youtube-GPT\\audios.mp4'

# %%
output = model.transcribe(r'C:\Users\ismae\Personal-Projects\Youtube-GPT\audios.mp4')
output
# Out:
# C:\Users\ismae\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\whisper\transcribe.py:79: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# {'text': " Hey, what's up, my KBHD here. So this little machine, this one right here that I can hold in my hands has more power than a base Mac Pro right now, more CPU power anyway. Now I hope that that's not true for much longer because the Mac Pro is overdue for its Apple Silicon upgrade. But the fact that it's true at all right now is absolutely insane. This little machine is not only super powerful and super efficient and super small, but it's also a really good price. So I said in my last video about the MacBook Pros that the Mac Mini is actually the more interesting machine. And I mean it, it really is. It's just gotten a refresh from the M1 chip that it had before to now having an M2 and an M2 Pro option, both of which are kind of game changers in their own ways. So first the M2 version, the base M2 Mac Mini is a game changer because it's all the benefits of the new Apple Silicon stuff, the second generation 5 and 8 meter process, the blazing fast shared memory, all the optimizations that come with it for a starting price of $599 US. So I mean it's a pretty simple computer, not even a small tower, just an absolutely tiny computer in there. It's basically the laptop, but without the screen and the keyboard. Only one color, silver, and then a decent selection of ports around the back along with a small exhaust vent for active cooling and a headphone jack. And so this thing packs a surprisingly enormous power for its size. We've seen this Apple Silicon transition play out over the past two years. And when the Mac Mini moved to Apple Silicon from the Intel chips, it took an absolutely hilarious leap up in performance. Some of the numbers on paper are just ridiculous. You have to forgive me for using Apple's stupid unlabeled charts, but like just to give you an idea, this completely changed the nature of the product. So this M1 Mac Mini is already dramatically better than the Intel one for 99% of people. And now the M2 comes along with more cores, a more powerful CPU and GPU, more max memory and a higher overall performance ceiling. And the price goes down from $699 to $599. Apple almost never lowers the price of the entry level of anything, but that's exactly what's happened here. We just got a computer that's more powerful and more capable and more efficient for less money. And so then we also have the M2 Pro Mac Mini. This is the one that I've been testing and using. And so before we just had the base Apple Silicon M1 Mac Mini, now that's the M2, but we've also now got this pro chip which raises the ceiling for Mac Mini performance still on the same tiny body. Well actually, I can't say the exact same tiny body because the M2 Pro version also does gain two more Thunderbolt ports. So now there's four Thunderbolt four ports on the back along with everything else still here. And that means you can now do three external displays instead of two. And you can still option up to 10 gigabit ethernet if you're blessed with that type of internet connection or if you're at an institution that will take advantage of the networking capability. And yes, that is HDMI 2.1. But the big deal here with this new chip is the M2 Pro is so much more performant thanks to the updated architecture and the extra cores that it's now benchmarking actually over the M1 Pro and the M1 Max in the CPU department that was in the highest end MacBook Pros before. I had to double take when I first read that because M1 Max has been so incredible. But yet here we are, even the incremental improvements here are notable. And on top of that, the thermal advantage potentially of a Mac Mini with active cooling in a taller chassis over a MacBook Pro can also mean in the long term, you know, sustained CPU performance over time. You may see even better results there. So this thing's performance is rock solid. And then of course, as you move up and chips from base to pro to max, that's actually mostly a GPU improvement. And so M2 Pro does great here too. But as you can s ...
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 4.6000000000000005,
#    'text': " Hey, what's up, my KBHD here.",
#    'tokens': [1911, 11, 437, 311, 493, 11, 452, 591, 33, 22859, 510, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2117495585962669,
#    'compression_ratio': 1.5560538116591929,
#    'no_speech_prob': 0.1567254513502121},
#   {'id': 1,
#    'seek': 0,
#    'start': 4.6000000000000005,
#    'end': 11.44,
#    'text': ' So this little machine, this one right here that I can hold in my hands has more power',
#    'tokens': [407,
#     341,
#     707,
#     3479,
#     11,
#     341,
#     472,
#     558,
#     510,
#     300,
#     286,
#     393,
#     1797,
#     294,
#     452,
#     2377,
#     575,
#     544,
#     1347],
#    'temperature': 0.0,
#    'avg_logprob': -0.2117495585962669,
#    'compression_ratio': 1.5560538116591929,
#    'no_speech_prob': 0.1567254513502121},
#   {'id': 2,
#    'seek': 0,
#    'start': 11.44,
#    'end': 16.0,
#    'text': ' than a base Mac Pro right now, more CPU power anyway.',
#    'tokens': [813,
#     257,
#     3096,
#     5707,
#     1705,
#     558,
#     586,
#     11,
#     544,
#     13199,
#     1347,
#     4033,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2117495585962669,
#    'compression_ratio': 1.5560538116591929,
#    'no_speech_prob': 0.1567254513502121},
#   {'id': 3,
#    'seek': 0,
#    'start': 16.0,
#    'end': 20.68,
#    'text': " Now I hope that that's not true for much longer because the Mac Pro is overdue for its",
#    'tokens': [823,
#     286,
#     1454,
#     300,
#     300,
#     311,
#     406,
#     2074,
#     337,
#     709,
#     2854,
#     570,
#     264,
#     5707,
#     1705,
#     307,
#     19853,
#     622,
#     337,
#     1080],
#    'temperature': 0.0,
#    'avg_logprob': -0.2117495585962669,
#    'compression_ratio': 1.5560538116591929,
#    'no_speech_prob': 0.1567254513502121},
#   {'id': 4,
#    'seek': 0,
#    'start': 20.68,
#    'end': 21.88,
#    'text': ' Apple Silicon upgrade.',
#    'tokens': [6373, 25351, 11484, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2117495585962669,
#    'compression_ratio': 1.5560538116591929,
#    'no_speech_prob': 0.1567254513502121},
#   {'id': 5,
#    'seek': 0,
#    'start': 21.88,
#    'end': 26.12,
#    'text': " But the fact that it's true at all right now is absolutely insane.",
#    'tokens': [583,
#     264,
#     1186,
#     300,
#     309,
#     311,
#     2074,
#     412,
#     439,
#     558,
#     586,
#     307,
#     3122,
#     10838,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2117495585962669,
#    'compression_ratio': 1.5560538116591929,
#    'no_speech_prob': 0.1567254513502121},
#   {'id': 6,
#    'seek': 2612,
#    'start': 26.12,
#    'end': 31.92,
#    'text': " This little machine is not only super powerful and super efficient and super small, but it's",
#    'tokens': [639,
#     707,
#     3479,
#     307,
#     406,
#     787,
#     1687,
#     4005,
#     293,
#     1687,
#     7148,
#     293,
#     1687,
#     1359,
#     11,
#     457,
#     309,
#     311],
#    'temperature': 0.0,
#    'avg_logprob': -0.1523676509350802,
#    'compression_ratio': 1.588679245283019,
#    'no_speech_prob': 0.0004922375082969666},
#   {'id': 7,
#    'seek': 2612,
#    'start': 31.92,
#    'end': 34.64,
#    'text': ' also a really good price.',
#    'tokens': [611, 257, 534, 665, 3218, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1523676509350802,
#    'compression_ratio': 1.588679245283019,
#    'no_speech_prob': 0.0004922375082969666},
#   {'id': 8,
#    'seek': 2612,
#    'start': 34.64,
#    'end': 38.760000000000005,
#    'text': ' So I said in my last video about the MacBook Pros that the Mac Mini is actually the more',
#    'tokens': [407,
#     286,
#     848,
#     294,
#     452,
#     1036,
#     960,
#     466,
#     264,
#     31737,
#     26024,
#     300,
#     264,
#     5707,
#     18239,
#     307,
#     767,
#     264,
#     544],
#    'temperature': 0.0,
#    'avg_logprob': -0.1523676509350802,
#    'compression_ratio': 1.588679245283019,
#    'no_speech_prob': 0.0004922375082969666},
#   {'id': 9,
#    'seek': 2612,
#    'start': 38.760000000000005,
#    'end': 40.04,
#    'text': ' interesting machine.',
#    'tokens': [1880, 3479, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1523676509350802,
#    'compression_ratio': 1.588679245283019,
#    'no_speech_prob': 0.0004922375082969666},
#   {'id': 10,
#    'seek': 2612,
#    'start': 40.04,
#    'end': 41.400000000000006,
#    'text': ' And I mean it, it really is.',
#    'tokens': [400, 286, 914, 309, 11, 309, 534, 307, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1523676509350802,
#    'compression_ratio': 1.588679245283019,
#    'no_speech_prob': 0.0004922375082969666},
#   {'id': 11,
#    'seek': 2612,
#    'start': 41.400000000000006,
#    'end': 46.96,
#    'text': " It's just gotten a refresh from the M1 chip that it had before to now having an M2",
#    'tokens': [467,
#     311,
#     445,
#     5768,
#     257,
#     15134,
#     490,
#     264,
#     376,
#     16,
#     11409,
#     300,
#     309,
#     632,
#     949,
#     281,
#     586,
#     1419,
#     364,
#     376,
#     17],
#    'temperature': 0.0,
#    'avg_logprob': -0.1523676509350802,
#    'compression_ratio': 1.588679245283019,
#    'no_speech_prob': 0.0004922375082969666},
#   {'id': 12,
#    'seek': 2612,
#    'start': 46.96,
#    'end': 51.28,
#    'text': ' and an M2 Pro option, both of which are kind of game changers in their own ways.',
#    'tokens': [293,
#     364,
#     376,
#     17,
#     1705,
#     3614,
#     11,
#     1293,
#     295,
#     597,
#     366,
#     733,
#     295,
#     1216,
#     1534,
#     433,
#     294,
#     641,
#     1065,
#     2098,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1523676509350802,
#    'compression_ratio': 1.588679245283019,
#    'no_speech_prob': 0.0004922375082969666},
#   {'id': 13,
#    'seek': 5128,
#    'start': 51.28,
#    'end': 56.92,
#    'text': " So first the M2 version, the base M2 Mac Mini is a game changer because it's all the benefits",
#    'tokens': [407,
#     700,
#     264,
#     376,
#     17,
#     3037,
#     11,
#     264,
#     3096,
#     376,
#     17,
#     5707,
#     18239,
#     307,
#     257,
#     1216,
#     22822,
#     570,
#     309,
#     311,
#     439,
#     264,
#     5311],
#    'temperature': 0.0,
#    'avg_logprob': -0.16948774305440611,
#    'compression_ratio': 1.5824561403508772,
#    'no_speech_prob': 5.6758159189485013e-05},
#   {'id': 14,
#    'seek': 5128,
#    'start': 56.92,
#    'end': 61.14,
#    'text': ' of the new Apple Silicon stuff, the second generation 5 and 8 meter process, the blazing',
#    'tokens': [295,
#     264,
#     777,
#     6373,
#     25351,
#     1507,
#     11,
#     264,
#     1150,
#     5125,
#     1025,
#     293,
#     1649,
#     9255,
#     1399,
#     11,
#     264,
#     16379,
#     8781],
#    'temperature': 0.0,
#    'avg_logprob': -0.16948774305440611,
#    'compression_ratio': 1.5824561403508772,
#    'no_speech_prob': 5.6758159189485013e-05},
#   {'id': 15,
#    'seek': 5128,
#    'start': 61.14,
#    'end': 68.44,
#    'text': ' fast shared memory, all the optimizations that come with it for a starting price of $599',
#    'tokens': [2370,
#     5507,
#     4675,
#     11,
#     439,
#     264,
#     5028,
#     14455,
#     300,
#     808,
#     365,
#     309,
#     337,
#     257,
#     2891,
#     3218,
#     295,
#     1848,
#     20,
#     8494],
#    'temperature': 0.0,
#    'avg_logprob': -0.16948774305440611,
#    'compression_ratio': 1.5824561403508772,
#    'no_speech_prob': 5.6758159189485013e-05},
#   {'id': 16,
#    'seek': 5128,
#    'start': 68.44,
#    'end': 69.44,
#    'text': ' US.',
#    'tokens': [2546, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.16948774305440611,
#    'compression_ratio': 1.5824561403508772,
#    'no_speech_prob': 5.6758159189485013e-05},
#   {'id': 17,
#    'seek': 5128,
#    'start': 69.44,
#    'end': 73.32,
#    'text': " So I mean it's a pretty simple computer, not even a small tower, just an absolutely tiny",
#    'tokens': [407,
#     286,
#     914,
#     309,
#     311,
#     257,
#     1238,
#     2199,
#     3820,
#     11,
#     406,
#     754,
#     257,
#     1359,
#     10567,
#     11,
#     445,
#     364,
#     3122,
#     5870],
#    'temperature': 0.0,
#    'avg_logprob': -0.16948774305440611,
#    'compression_ratio': 1.5824561403508772,
#    'no_speech_prob': 5.6758159189485013e-05},
#   {'id': 18,
#    'seek': 5128,
#    'start': 73.32,
#    'end': 74.32,
#    'text': ' computer in there.',
#    'tokens': [3820, 294, 456, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.16948774305440611,
#    'compression_ratio': 1.5824561403508772,
#    'no_speech_prob': 5.6758159189485013e-05},
#   {'id': 19,
#    'seek': 5128,
#    'start': 74.32,
#    'end': 78.04,
#    'text': " It's basically the laptop, but without the screen and the keyboard.",
#    'tokens': [467,
#     311,
#     1936,
#     264,
#     10732,
#     11,
#     457,
#     1553,
#     264,
#     2568,
#     293,
#     264,
#     10186,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.16948774305440611,
#    'compression_ratio': 1.5824561403508772,
#    'no_speech_prob': 5.6758159189485013e-05},
#   {'id': 20,
#    'seek': 7804,
#    'start': 78.04,
#    'end': 82.16000000000001,
#    'text': ' Only one color, silver, and then a decent selection of ports around the back along with',
#    'tokens': [5686,
#     472,
#     2017,
#     11,
#     8753,
#     11,
#     293,
#     550,
#     257,
#     8681,
#     9450,
#     295,
#     18160,
#     926,
#     264,
#     646,
#     2051,
#     365],
#    'temperature': 0.0,
#    'avg_logprob': -0.13624129662146936,
#    'compression_ratio': 1.6458333333333333,
#    'no_speech_prob': 6.126432708697394e-05},
#   {'id': 21,
#    'seek': 7804,
#    'start': 82.16000000000001,
#    'end': 86.04,
#    'text': ' a small exhaust vent for active cooling and a headphone jack.',
#    'tokens': [257,
#     1359,
#     14687,
#     6931,
#     337,
#     4967,
#     14785,
#     293,
#     257,
#     35028,
#     7109,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13624129662146936,
#    'compression_ratio': 1.6458333333333333,
#    'no_speech_prob': 6.126432708697394e-05},
#   {'id': 22,
#    'seek': 7804,
#    'start': 86.04,
#    'end': 90.28,
#    'text': ' And so this thing packs a surprisingly enormous power for its size.',
#    'tokens': [400,
#     370,
#     341,
#     551,
#     19403,
#     257,
#     17600,
#     11322,
#     1347,
#     337,
#     1080,
#     2744,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13624129662146936,
#    'compression_ratio': 1.6458333333333333,
#    'no_speech_prob': 6.126432708697394e-05},
#   {'id': 23,
#    'seek': 7804,
#    'start': 90.28,
#    'end': 93.64,
#    'text': " We've seen this Apple Silicon transition play out over the past two years.",
#    'tokens': [492,
#     600,
#     1612,
#     341,
#     6373,
#     25351,
#     6034,
#     862,
#     484,
#     670,
#     264,
#     1791,
#     732,
#     924,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13624129662146936,
#    'compression_ratio': 1.6458333333333333,
#    'no_speech_prob': 6.126432708697394e-05},
#   {'id': 24,
#    'seek': 7804,
#    'start': 93.64,
#    'end': 99.0,
#    'text': ' And when the Mac Mini moved to Apple Silicon from the Intel chips, it took an absolutely',
#    'tokens': [400,
#     562,
#     264,
#     5707,
#     18239,
#     4259,
#     281,
#     6373,
#     25351,
#     490,
#     264,
#     19762,
#     11583,
#     11,
#     309,
#     1890,
#     364,
#     3122],
#    'temperature': 0.0,
#    'avg_logprob': -0.13624129662146936,
#    'compression_ratio': 1.6458333333333333,
#    'no_speech_prob': 6.126432708697394e-05},
#   {'id': 25,
#    'seek': 7804,
#    'start': 99.0,
#    'end': 101.28,
#    'text': ' hilarious leap up in performance.',
#    'tokens': [19796, 19438, 493, 294, 3389, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13624129662146936,
#    'compression_ratio': 1.6458333333333333,
#    'no_speech_prob': 6.126432708697394e-05},
#   {'id': 26,
#    'seek': 7804,
#    'start': 101.28,
#    'end': 103.12,
#    'text': ' Some of the numbers on paper are just ridiculous.',
#    'tokens': [2188, 295, 264, 3547, 322, 3035, 366, 445, 11083, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13624129662146936,
#    'compression_ratio': 1.6458333333333333,
#    'no_speech_prob': 6.126432708697394e-05},
#   {'id': 27,
#    'seek': 7804,
#    'start': 103.12,
#    'end': 107.88000000000001,
#    'text': " You have to forgive me for using Apple's stupid unlabeled charts, but like just to give",
#    'tokens': [509,
#     362,
#     281,
#     10718,
#     385,
#     337,
#     1228,
#     6373,
#     311,
#     6631,
#     32118,
#     18657,
#     292,
#     17767,
#     11,
#     457,
#     411,
#     445,
#     281,
#     976],
#    'temperature': 0.0,
#    'avg_logprob': -0.13624129662146936,
#    'compression_ratio': 1.6458333333333333,
#    'no_speech_prob': 6.126432708697394e-05},
#   {'id': 28,
#    'seek': 10788,
#    'start': 107.88,
#    'end': 111.44,
#    'text': ' you an idea, this completely changed the nature of the product.',
#    'tokens': [291,
#     364,
#     1558,
#     11,
#     341,
#     2584,
#     3105,
#     264,
#     3687,
#     295,
#     264,
#     1674,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.10697359743371473,
#    'compression_ratio': 1.5263157894736843,
#    'no_speech_prob': 3.013294372067321e-05},
#   {'id': 29,
#    'seek': 10788,
#    'start': 111.44,
#    'end': 115.92,
#    'text': ' So this M1 Mac Mini is already dramatically better than the Intel one for 99% of people.',
#    'tokens': [407,
#     341,
#     376,
#     16,
#     5707,
#     18239,
#     307,
#     1217,
#     17548,
#     1101,
#     813,
#     264,
#     19762,
#     472,
#     337,
#     11803,
#     4,
#     295,
#     561,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.10697359743371473,
#    'compression_ratio': 1.5263157894736843,
#    'no_speech_prob': 3.013294372067321e-05},
#   {'id': 30,
#    'seek': 10788,
#    'start': 115.92,
#    'end': 122.88,
#    'text': ' And now the M2 comes along with more cores, a more powerful CPU and GPU, more max memory',
#    'tokens': [400,
#     586,
#     264,
#     376,
#     17,
#     1487,
#     2051,
#     365,
#     544,
#     24826,
#     11,
#     257,
#     544,
#     4005,
#     13199,
#     293,
#     18407,
#     11,
#     544,
#     11469,
#     4675],
#    'temperature': 0.0,
#    'avg_logprob': -0.10697359743371473,
#    'compression_ratio': 1.5263157894736843,
#    'no_speech_prob': 3.013294372067321e-05},
#   {'id': 31,
#    'seek': 10788,
#    'start': 122.88,
#    'end': 125.28,
#    'text': ' and a higher overall performance ceiling.',
#    'tokens': [293, 257, 2946, 4787, 3389, 13655, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.10697359743371473,
#    'compression_ratio': 1.5263157894736843,
#    'no_speech_prob': 3.013294372067321e-05},
#   {'id': 32,
#    'seek': 10788,
#    'start': 125.28,
#    'end': 130.4,
#    'text': ' And the price goes down from $699 to $599.',
#    'tokens': [400,
#     264,
#     3218,
#     1709,
#     760,
#     490,
#     1848,
#     21,
#     8494,
#     281,
#     1848,
#     20,
#     8494,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.10697359743371473,
#    'compression_ratio': 1.5263157894736843,
#    'no_speech_prob': 3.013294372067321e-05},
#   {'id': 33,
#    'seek': 10788,
#    'start': 130.4,
#    'end': 133.8,
#    'text': " Apple almost never lowers the price of the entry level of anything, but that's exactly",
#    'tokens': [6373,
#     1920,
#     1128,
#     44936,
#     264,
#     3218,
#     295,
#     264,
#     8729,
#     1496,
#     295,
#     1340,
#     11,
#     457,
#     300,
#     311,
#     2293],
#    'temperature': 0.0,
#    'avg_logprob': -0.10697359743371473,
#    'compression_ratio': 1.5263157894736843,
#    'no_speech_prob': 3.013294372067321e-05},
#   {'id': 34,
#    'seek': 10788,
#    'start': 133.8,
#    'end': 134.8,
#    'text': " what's happened here.",
#    'tokens': [437, 311, 2011, 510, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.10697359743371473,
#    'compression_ratio': 1.5263157894736843,
#    'no_speech_prob': 3.013294372067321e-05},
#   {'id': 35,
#    'seek': 13480,
#    'start': 134.8,
#    'end': 140.84,
#    'text': " We just got a computer that's more powerful and more capable and more efficient for less",
#    'tokens': [492,
#     445,
#     658,
#     257,
#     3820,
#     300,
#     311,
#     544,
#     4005,
#     293,
#     544,
#     8189,
#     293,
#     544,
#     7148,
#     337,
#     1570],
#    'temperature': 0.0,
#    'avg_logprob': -0.15710364282131195,
#    'compression_ratio': 1.697508896797153,
#    'no_speech_prob': 2.0280540411476977e-05},
#   {'id': 36,
#    'seek': 13480,
#    'start': 140.84,
#    'end': 141.84,
#    'text': ' money.',
#    'tokens': [1460, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15710364282131195,
#    'compression_ratio': 1.697508896797153,
#    'no_speech_prob': 2.0280540411476977e-05},
#   {'id': 37,
#    'seek': 13480,
#    'start': 141.84,
#    'end': 144.24,
#    'text': ' And so then we also have the M2 Pro Mac Mini.',
#    'tokens': [400,
#     370,
#     550,
#     321,
#     611,
#     362,
#     264,
#     376,
#     17,
#     1705,
#     5707,
#     18239,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15710364282131195,
#    'compression_ratio': 1.697508896797153,
#    'no_speech_prob': 2.0280540411476977e-05},
#   {'id': 38,
#    'seek': 13480,
#    'start': 144.24,
#    'end': 146.44,
#    'text': " This is the one that I've been testing and using.",
#    'tokens': [639, 307, 264, 472, 300, 286, 600, 668, 4997, 293, 1228, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15710364282131195,
#    'compression_ratio': 1.697508896797153,
#    'no_speech_prob': 2.0280540411476977e-05},
#   {'id': 39,
#    'seek': 13480,
#    'start': 146.44,
#    'end': 151.20000000000002,
#    'text': " And so before we just had the base Apple Silicon M1 Mac Mini, now that's the M2, but we've",
#    'tokens': [400,
#     370,
#     949,
#     321,
#     445,
#     632,
#     264,
#     3096,
#     6373,
#     25351,
#     376,
#     16,
#     5707,
#     18239,
#     11,
#     586,
#     300,
#     311,
#     264,
#     376,
#     17,
#     11,
#     457,
#     321,
#     600],
#    'temperature': 0.0,
#    'avg_logprob': -0.15710364282131195,
#    'compression_ratio': 1.697508896797153,
#    'no_speech_prob': 2.0280540411476977e-05},
#   {'id': 40,
#    'seek': 13480,
#    'start': 151.20000000000002,
#    'end': 157.36,
#    'text': ' also now got this pro chip which raises the ceiling for Mac Mini performance still on the',
#    'tokens': [611,
#     586,
#     658,
#     341,
#     447,
#     11409,
#     597,
#     19658,
#     264,
#     13655,
#     337,
#     5707,
#     18239,
#     3389,
#     920,
#     322,
#     264],
#    'temperature': 0.0,
#    'avg_logprob': -0.15710364282131195,
#    'compression_ratio': 1.697508896797153,
#    'no_speech_prob': 2.0280540411476977e-05},
#   {'id': 41,
#    'seek': 13480,
#    'start': 157.36,
#    'end': 158.36,
#    'text': ' same tiny body.',
#    'tokens': [912, 5870, 1772, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15710364282131195,
#    'compression_ratio': 1.697508896797153,
#    'no_speech_prob': 2.0280540411476977e-05},
#   {'id': 42,
#    'seek': 13480,
#    'start': 158.36,
#    'end': 162.56,
#    'text': " Well actually, I can't say the exact same tiny body because the M2 Pro version also does",
#    'tokens': [1042,
#     767,
#     11,
#     286,
#     393,
#     380,
#     584,
#     264,
#     1900,
#     912,
#     5870,
#     1772,
#     570,
#     264,
#     376,
#     17,
#     1705,
#     3037,
#     611,
#     775],
#    'temperature': 0.0,
#    'avg_logprob': -0.15710364282131195,
#    'compression_ratio': 1.697508896797153,
#    'no_speech_prob': 2.0280540411476977e-05},
#   {'id': 43,
#    'seek': 16256,
#    'start': 162.56,
#    'end': 164.84,
#    'text': ' gain two more Thunderbolt ports.',
#    'tokens': [6052, 732, 544, 21023, 39477, 18160, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15367940068244934,
#    'compression_ratio': 1.6889632107023411,
#    'no_speech_prob': 7.082848605932668e-05},
#   {'id': 44,
#    'seek': 16256,
#    'start': 164.84,
#    'end': 167.72,
#    'text': " So now there's four Thunderbolt four ports on the back along with everything else still",
#    'tokens': [407,
#     586,
#     456,
#     311,
#     1451,
#     21023,
#     39477,
#     1451,
#     18160,
#     322,
#     264,
#     646,
#     2051,
#     365,
#     1203,
#     1646,
#     920],
#    'temperature': 0.0,
#    'avg_logprob': -0.15367940068244934,
#    'compression_ratio': 1.6889632107023411,
#    'no_speech_prob': 7.082848605932668e-05},
#   {'id': 45,
#    'seek': 16256,
#    'start': 167.72,
#    'end': 168.72,
#    'text': ' here.',
#    'tokens': [510, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15367940068244934,
#    'compression_ratio': 1.6889632107023411,
#    'no_speech_prob': 7.082848605932668e-05},
#   {'id': 46,
#    'seek': 16256,
#    'start': 168.72,
#    'end': 172.6,
#    'text': ' And that means you can now do three external displays instead of two.',
#    'tokens': [400,
#     300,
#     1355,
#     291,
#     393,
#     586,
#     360,
#     1045,
#     8320,
#     20119,
#     2602,
#     295,
#     732,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15367940068244934,
#    'compression_ratio': 1.6889632107023411,
#    'no_speech_prob': 7.082848605932668e-05},
#   {'id': 47,
#    'seek': 16256,
#    'start': 172.6,
#    'end': 176.44,
#    'text': " And you can still option up to 10 gigabit ethernet if you're blessed with that type of internet",
#    'tokens': [400,
#     291,
#     393,
#     920,
#     3614,
#     493,
#     281,
#     1266,
#     8741,
#     455,
#     270,
#     37096,
#     7129,
#     498,
#     291,
#     434,
#     12351,
#     365,
#     300,
#     2010,
#     295,
#     4705],
#    'temperature': 0.0,
#    'avg_logprob': -0.15367940068244934,
#    'compression_ratio': 1.6889632107023411,
#    'no_speech_prob': 7.082848605932668e-05},
#   {'id': 48,
#    'seek': 16256,
#    'start': 176.44,
#    'end': 181.32,
#    'text': " connection or if you're at an institution that will take advantage of the networking capability.",
#    'tokens': [4984,
#     420,
#     498,
#     291,
#     434,
#     412,
#     364,
#     7818,
#     300,
#     486,
#     747,
#     5002,
#     295,
#     264,
#     17985,
#     13759,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15367940068244934,
#    'compression_ratio': 1.6889632107023411,
#    'no_speech_prob': 7.082848605932668e-05},
#   {'id': 49,
#    'seek': 16256,
#    'start': 181.32,
#    'end': 183.4,
#    'text': ' And yes, that is HDMI 2.1.',
#    'tokens': [400, 2086, 11, 300, 307, 30811, 568, 13, 16, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15367940068244934,
#    'compression_ratio': 1.6889632107023411,
#    'no_speech_prob': 7.082848605932668e-05},
#   {'id': 50,
#    'seek': 16256,
#    'start': 183.4,
#    'end': 188.12,
#    'text': ' But the big deal here with this new chip is the M2 Pro is so much more performant thanks',
#    'tokens': [583,
#     264,
#     955,
#     2028,
#     510,
#     365,
#     341,
#     777,
#     11409,
#     307,
#     264,
#     376,
#     17,
#     1705,
#     307,
#     370,
#     709,
#     544,
#     2042,
#     394,
#     3231],
#    'temperature': 0.0,
#    'avg_logprob': -0.15367940068244934,
#    'compression_ratio': 1.6889632107023411,
#    'no_speech_prob': 7.082848605932668e-05},
#   {'id': 51,
#    'seek': 18812,
#    'start': 188.12,
#    'end': 193.4,
#    'text': " to the updated architecture and the extra cores that it's now benchmarking actually over",
#    'tokens': [281,
#     264,
#     10588,
#     9482,
#     293,
#     264,
#     2857,
#     24826,
#     300,
#     309,
#     311,
#     586,
#     18927,
#     278,
#     767,
#     670],
#    'temperature': 0.0,
#    'avg_logprob': -0.1466561977679913,
#    'compression_ratio': 1.6830769230769231,
#    'no_speech_prob': 5.864383638254367e-05},
#   {'id': 52,
#    'seek': 18812,
#    'start': 193.4,
#    'end': 199.28,
#    'text': ' the M1 Pro and the M1 Max in the CPU department that was in the highest end MacBook Pros before.',
#    'tokens': [264,
#     376,
#     16,
#     1705,
#     293,
#     264,
#     376,
#     16,
#     7402,
#     294,
#     264,
#     13199,
#     5882,
#     300,
#     390,
#     294,
#     264,
#     6343,
#     917,
#     31737,
#     26024,
#     949,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1466561977679913,
#    'compression_ratio': 1.6830769230769231,
#    'no_speech_prob': 5.864383638254367e-05},
#   {'id': 53,
#    'seek': 18812,
#    'start': 199.28,
#    'end': 203.68,
#    'text': ' I had to double take when I first read that because M1 Max has been so incredible.',
#    'tokens': [286,
#     632,
#     281,
#     3834,
#     747,
#     562,
#     286,
#     700,
#     1401,
#     300,
#     570,
#     376,
#     16,
#     7402,
#     575,
#     668,
#     370,
#     4651,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1466561977679913,
#    'compression_ratio': 1.6830769230769231,
#    'no_speech_prob': 5.864383638254367e-05},
#   {'id': 54,
#    'seek': 18812,
#    'start': 203.68,
#    'end': 207.16,
#    'text': ' But yet here we are, even the incremental improvements here are notable.',
#    'tokens': [583,
#     1939,
#     510,
#     321,
#     366,
#     11,
#     754,
#     264,
#     35759,
#     13797,
#     510,
#     366,
#     22556,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1466561977679913,
#    'compression_ratio': 1.6830769230769231,
#    'no_speech_prob': 5.864383638254367e-05},
#   {'id': 55,
#    'seek': 18812,
#    'start': 207.16,
#    'end': 211.32,
#    'text': ' And on top of that, the thermal advantage potentially of a Mac Mini with active cooling',
#    'tokens': [400,
#     322,
#     1192,
#     295,
#     300,
#     11,
#     264,
#     15070,
#     5002,
#     7263,
#     295,
#     257,
#     5707,
#     18239,
#     365,
#     4967,
#     14785],
#    'temperature': 0.0,
#    'avg_logprob': -0.1466561977679913,
#    'compression_ratio': 1.6830769230769231,
#    'no_speech_prob': 5.864383638254367e-05},
#   {'id': 56,
#    'seek': 18812,
#    'start': 211.32,
#    'end': 215.92000000000002,
#    'text': ' in a taller chassis over a MacBook Pro can also mean in the long term, you know, sustained',
#    'tokens': [294,
#     257,
#     22406,
#     28262,
#     670,
#     257,
#     31737,
#     1705,
#     393,
#     611,
#     914,
#     294,
#     264,
#     938,
#     1433,
#     11,
#     291,
#     458,
#     11,
#     23389],
#    'temperature': 0.0,
#    'avg_logprob': -0.1466561977679913,
#    'compression_ratio': 1.6830769230769231,
#    'no_speech_prob': 5.864383638254367e-05},
#   {'id': 57,
#    'seek': 18812,
#    'start': 215.92000000000002,
#    'end': 217.68,
#    'text': ' CPU performance over time.',
#    'tokens': [13199, 3389, 670, 565, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1466561977679913,
#    'compression_ratio': 1.6830769230769231,
#    'no_speech_prob': 5.864383638254367e-05},
#   {'id': 58,
#    'seek': 21768,
#    'start': 217.68,
#    'end': 219.44,
#    'text': ' You may see even better results there.',
#    'tokens': [509, 815, 536, 754, 1101, 3542, 456, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14288613494013397,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 5.874318958376534e-05},
#   {'id': 59,
#    'seek': 21768,
#    'start': 219.44,
#    'end': 222.4,
#    'text': " So this thing's performance is rock solid.",
#    'tokens': [407, 341, 551, 311, 3389, 307, 3727, 5100, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14288613494013397,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 5.874318958376534e-05},
#   {'id': 60,
#    'seek': 21768,
#    'start': 222.4,
#    'end': 226.68,
#    'text': " And then of course, as you move up and chips from base to pro to max, that's actually",
#    'tokens': [400,
#     550,
#     295,
#     1164,
#     11,
#     382,
#     291,
#     1286,
#     493,
#     293,
#     11583,
#     490,
#     3096,
#     281,
#     447,
#     281,
#     11469,
#     11,
#     300,
#     311,
#     767],
#    'temperature': 0.0,
#    'avg_logprob': -0.14288613494013397,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 5.874318958376534e-05},
#   {'id': 61,
#    'seek': 21768,
#    'start': 226.68,
#    'end': 228.52,
#    'text': ' mostly a GPU improvement.',
#    'tokens': [5240, 257, 18407, 10444, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14288613494013397,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 5.874318958376534e-05},
#   {'id': 62,
#    'seek': 21768,
#    'start': 228.52,
#    'end': 231.24,
#    'text': ' And so M2 Pro does great here too.',
#    'tokens': [400, 370, 376, 17, 1705, 775, 869, 510, 886, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14288613494013397,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 5.874318958376534e-05},
#   {'id': 63,
#    'seek': 21768,
#    'start': 231.24,
#    'end': 233.8,
#    'text': ' But as you can see, the results fall sort of more online.',
#    'tokens': [583,
#     382,
#     291,
#     393,
#     536,
#     11,
#     264,
#     3542,
#     2100,
#     1333,
#     295,
#     544,
#     2950,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14288613494013397,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 5.874318958376534e-05},
#   {'id': 64,
#    'seek': 21768,
#    'start': 233.8,
#    'end': 235.48000000000002,
#    'text': " It's improvement, of course, over the last one.",
#    'tokens': [467, 311, 10444, 11, 295, 1164, 11, 670, 264, 1036, 472, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14288613494013397,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 5.874318958376534e-05},
#   {'id': 65,
#    'seek': 21768,
#    'start': 235.48000000000002,
#    'end': 240.60000000000002,
#    'text': ' But the max chips are still the way to go if your applications specifically take advantage',
#    'tokens': [583,
#     264,
#     11469,
#     11583,
#     366,
#     920,
#     264,
#     636,
#     281,
#     352,
#     498,
#     428,
#     5821,
#     4682,
#     747,
#     5002],
#    'temperature': 0.0,
#    'avg_logprob': -0.14288613494013397,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 5.874318958376534e-05},
#   {'id': 66,
#    'seek': 21768,
#    'start': 240.60000000000002,
#    'end': 242.44,
#    'text': ' of GPU power.',
#    'tokens': [295, 18407, 1347, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14288613494013397,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 5.874318958376534e-05},
#   {'id': 67,
#    'seek': 21768,
#    'start': 242.44,
#    'end': 247.28,
#    'text': " But then every day performance is just it's going to be the same, which is to say great.",
#    'tokens': [583,
#     550,
#     633,
#     786,
#     3389,
#     307,
#     445,
#     309,
#     311,
#     516,
#     281,
#     312,
#     264,
#     912,
#     11,
#     597,
#     307,
#     281,
#     584,
#     869,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14288613494013397,
#    'compression_ratio': 1.6923076923076923,
#    'no_speech_prob': 5.874318958376534e-05},
#   {'id': 68,
#    'seek': 24728,
#    'start': 247.28,
#    'end': 251.76,
#    'text': ' But the sustained multi-core performance ceiling is just way higher, you know, especially',
#    'tokens': [583,
#     264,
#     23389,
#     4825,
#     12,
#     12352,
#     3389,
#     13655,
#     307,
#     445,
#     636,
#     2946,
#     11,
#     291,
#     458,
#     11,
#     2318],
#    'temperature': 0.0,
#    'avg_logprob': -0.1630579630533854,
#    'compression_ratio': 1.596551724137931,
#    'no_speech_prob': 4.158685260335915e-05},
#   {'id': 69,
#    'seek': 24728,
#    'start': 251.76,
#    'end': 254.76,
#    'text': ' for things like video editing or app development.',
#    'tokens': [337, 721, 411, 960, 10000, 420, 724, 3250, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1630579630533854,
#    'compression_ratio': 1.596551724137931,
#    'no_speech_prob': 4.158685260335915e-05},
#   {'id': 70,
#    'seek': 24728,
#    'start': 254.76,
#    'end': 258.32,
#    'text': ' Things that have basically longer compile times or render times that might be above what',
#    'tokens': [9514,
#     300,
#     362,
#     1936,
#     2854,
#     31413,
#     1413,
#     420,
#     15529,
#     1413,
#     300,
#     1062,
#     312,
#     3673,
#     437],
#    'temperature': 0.0,
#    'avg_logprob': -0.1630579630533854,
#    'compression_ratio': 1.596551724137931,
#    'no_speech_prob': 4.158685260335915e-05},
#   {'id': 71,
#    'seek': 24728,
#    'start': 258.32,
#    'end': 261.64,
#    'text': " you want to do on the base M2, that's awesome on the M2 Pro.",
#    'tokens': [291,
#     528,
#     281,
#     360,
#     322,
#     264,
#     3096,
#     376,
#     17,
#     11,
#     300,
#     311,
#     3476,
#     322,
#     264,
#     376,
#     17,
#     1705,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1630579630533854,
#    'compression_ratio': 1.596551724137931,
#    'no_speech_prob': 4.158685260335915e-05},
#   {'id': 72,
#    'seek': 24728,
#    'start': 261.64,
#    'end': 264.08,
#    'text': ' This model starts at 1299.',
#    'tokens': [639, 2316, 3719, 412, 2272, 8494, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1630579630533854,
#    'compression_ratio': 1.596551724137931,
#    'no_speech_prob': 4.158685260335915e-05},
#   {'id': 73,
#    'seek': 24728,
#    'start': 264.08,
#    'end': 269.48,
#    'text': ' Not cheap, of course, but when you consider the M2 Pro MacBook Pro with the exact same system',
#    'tokens': [1726,
#     7084,
#     11,
#     295,
#     1164,
#     11,
#     457,
#     562,
#     291,
#     1949,
#     264,
#     376,
#     17,
#     1705,
#     31737,
#     1705,
#     365,
#     264,
#     1900,
#     912,
#     1185],
#    'temperature': 0.0,
#    'avg_logprob': -0.1630579630533854,
#    'compression_ratio': 1.596551724137931,
#    'no_speech_prob': 4.158685260335915e-05},
#   {'id': 74,
#    'seek': 24728,
#    'start': 269.48,
#    'end': 273.04,
#    'text': ' on a chip starts at 1990, 99 right now.',
#    'tokens': [322, 257, 11409, 3719, 412, 13384, 11, 11803, 558, 586, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1630579630533854,
#    'compression_ratio': 1.596551724137931,
#    'no_speech_prob': 4.158685260335915e-05},
#   {'id': 75,
#    'seek': 24728,
#    'start': 273.04,
#    'end': 274.04,
#    'text': ' Pretty good.',
#    'tokens': [10693, 665, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1630579630533854,
#    'compression_ratio': 1.596551724137931,
#    'no_speech_prob': 4.158685260335915e-05},
#   {'id': 76,
#    'seek': 27404,
#    'start': 274.04,
#    'end': 278.08000000000004,
#    'text': " And that's the real reason I'm calling these Mac Minis a game changer, or at least for",
#    'tokens': [400,
#     300,
#     311,
#     264,
#     957,
#     1778,
#     286,
#     478,
#     5141,
#     613,
#     5707,
#     2829,
#     271,
#     257,
#     1216,
#     22822,
#     11,
#     420,
#     412,
#     1935,
#     337],
#    'temperature': 0.0,
#    'avg_logprob': -0.15556683259851792,
#    'compression_ratio': 1.8187134502923976,
#    'no_speech_prob': 0.00021224313240963966},
#   {'id': 77,
#    'seek': 27404,
#    'start': 278.08000000000004,
#    'end': 281.52000000000004,
#    'text': ' being so good, is performance per dollar.',
#    'tokens': [885, 370, 665, 11, 307, 3389, 680, 7241, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15556683259851792,
#    'compression_ratio': 1.8187134502923976,
#    'no_speech_prob': 0.00021224313240963966},
#   {'id': 78,
#    'seek': 27404,
#    'start': 281.52000000000004,
#    'end': 284.8,
#    'text': " You don't usually expect that out of a Mac, but if I were to do like one of those dumb",
#    'tokens': [509,
#     500,
#     380,
#     2673,
#     2066,
#     300,
#     484,
#     295,
#     257,
#     5707,
#     11,
#     457,
#     498,
#     286,
#     645,
#     281,
#     360,
#     411,
#     472,
#     295,
#     729,
#     10316],
#    'temperature': 0.0,
#    'avg_logprob': -0.15556683259851792,
#    'compression_ratio': 1.8187134502923976,
#    'no_speech_prob': 0.00021224313240963966},
#   {'id': 79,
#    'seek': 27404,
#    'start': 284.8,
#    'end': 288.16,
#    'text': " Apple charts of like, here's the laptops performance per dollar.",
#    'tokens': [6373,
#     17767,
#     295,
#     411,
#     11,
#     510,
#     311,
#     264,
#     27642,
#     3389,
#     680,
#     7241,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15556683259851792,
#    'compression_ratio': 1.8187134502923976,
#    'no_speech_prob': 0.00021224313240963966},
#   {'id': 80,
#    'seek': 27404,
#    'start': 288.16,
#    'end': 291.56,
#    'text': " And then here's the Mac Minis, which is the same performance, but for less money.",
#    'tokens': [400,
#     550,
#     510,
#     311,
#     264,
#     5707,
#     2829,
#     271,
#     11,
#     597,
#     307,
#     264,
#     912,
#     3389,
#     11,
#     457,
#     337,
#     1570,
#     1460,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15556683259851792,
#    'compression_ratio': 1.8187134502923976,
#    'no_speech_prob': 0.00021224313240963966},
#   {'id': 81,
#    'seek': 27404,
#    'start': 291.56,
#    'end': 292.84000000000003,
#    'text': " It's better, the line's higher.",
#    'tokens': [467, 311, 1101, 11, 264, 1622, 311, 2946, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15556683259851792,
#    'compression_ratio': 1.8187134502923976,
#    'no_speech_prob': 0.00021224313240963966},
#   {'id': 82,
#    'seek': 27404,
#    'start': 292.84000000000003,
#    'end': 296.24,
#    'text': " You know, for so long, Apple's prioritized these laptops, which makes perfect sense,",
#    'tokens': [509,
#     458,
#     11,
#     337,
#     370,
#     938,
#     11,
#     6373,
#     311,
#     14846,
#     1602,
#     613,
#     27642,
#     11,
#     597,
#     1669,
#     2176,
#     2020,
#     11],
#    'temperature': 0.0,
#    'avg_logprob': -0.15556683259851792,
#    'compression_ratio': 1.8187134502923976,
#    'no_speech_prob': 0.00021224313240963966},
#   {'id': 83,
#    'seek': 27404,
#    'start': 296.24,
#    'end': 297.24,
#    'text': ' by the way.',
#    'tokens': [538, 264, 636, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15556683259851792,
#    'compression_ratio': 1.8187134502923976,
#    'no_speech_prob': 0.00021224313240963966},
#   {'id': 84,
#    'seek': 27404,
#    'start': 297.24,
#    'end': 298.24,
#    'text': " They've been great.",
#    'tokens': [814, 600, 668, 869, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15556683259851792,
#    'compression_ratio': 1.8187134502923976,
#    'no_speech_prob': 0.00021224313240963966},
#   {'id': 85,
#    'seek': 27404,
#    'start': 298.24,
#    'end': 299.24,
#    'text': ' Lots of people buy them.',
#    'tokens': [15908, 295, 561, 2256, 552, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15556683259851792,
#    'compression_ratio': 1.8187134502923976,
#    'no_speech_prob': 0.00021224313240963966},
#   {'id': 86,
#    'seek': 27404,
#    'start': 299.24,
#    'end': 303.16,
#    'text': ' But some people get the laptop and then just keep it in one room all the time because',
#    'tokens': [583,
#     512,
#     561,
#     483,
#     264,
#     10732,
#     293,
#     550,
#     445,
#     1066,
#     309,
#     294,
#     472,
#     1808,
#     439,
#     264,
#     565,
#     570],
#    'temperature': 0.0,
#    'avg_logprob': -0.15556683259851792,
#    'compression_ratio': 1.8187134502923976,
#    'no_speech_prob': 0.00021224313240963966},
#   {'id': 87,
#    'seek': 30316,
#    'start': 303.16,
#    'end': 305.48,
#    'text': " desktop options aren't as appealing.",
#    'tokens': [14502, 3956, 3212, 380, 382, 23842, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14848303968888998,
#    'compression_ratio': 1.627906976744186,
#    'no_speech_prob': 0.00010218867100775242},
#   {'id': 88,
#    'seek': 30316,
#    'start': 305.48,
#    'end': 309.52000000000004,
#    'text': " And for being honest, the iMac is cool, but it's not for everyone.",
#    'tokens': [400,
#     337,
#     885,
#     3245,
#     11,
#     264,
#     741,
#     34355,
#     307,
#     1627,
#     11,
#     457,
#     309,
#     311,
#     406,
#     337,
#     1518,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14848303968888998,
#    'compression_ratio': 1.627906976744186,
#    'no_speech_prob': 0.00010218867100775242},
#   {'id': 89,
#    'seek': 30316,
#    'start': 309.52000000000004,
#    'end': 313.24,
#    'text': ' Like even right now, it kind of feels like Apple low key forgot about the iMac.',
#    'tokens': [1743,
#     754,
#     558,
#     586,
#     11,
#     309,
#     733,
#     295,
#     3417,
#     411,
#     6373,
#     2295,
#     2141,
#     5298,
#     466,
#     264,
#     741,
#     34355,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14848303968888998,
#    'compression_ratio': 1.627906976744186,
#    'no_speech_prob': 0.00010218867100775242},
#   {'id': 90,
#    'seek': 30316,
#    'start': 313.24,
#    'end': 317.16,
#    'text': " It's just been sitting with the unupgraded M1 chip for a little while now, even when",
#    'tokens': [467,
#     311,
#     445,
#     668,
#     3798,
#     365,
#     264,
#     517,
#     1010,
#     7165,
#     292,
#     376,
#     16,
#     11409,
#     337,
#     257,
#     707,
#     1339,
#     586,
#     11,
#     754,
#     562],
#    'temperature': 0.0,
#    'avg_logprob': -0.14848303968888998,
#    'compression_ratio': 1.627906976744186,
#    'no_speech_prob': 0.00010218867100775242},
#   {'id': 91,
#    'seek': 30316,
#    'start': 317.16,
#    'end': 318.16,
#    'text': ' M2 is out.',
#    'tokens': [376, 17, 307, 484, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14848303968888998,
#    'compression_ratio': 1.627906976744186,
#    'no_speech_prob': 0.00010218867100775242},
#   {'id': 92,
#    'seek': 30316,
#    'start': 318.16,
#    'end': 319.64000000000004,
#    'text': ' But then they dropped Mac Studio.',
#    'tokens': [583, 550, 436, 8119, 5707, 13500, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14848303968888998,
#    'compression_ratio': 1.627906976744186,
#    'no_speech_prob': 0.00010218867100775242},
#   {'id': 93,
#    'seek': 30316,
#    'start': 319.64000000000004,
#    'end': 323.68,
#    'text': " And Mac Studio is excellent in the highest end configurations, and I can't wait for the",
#    'tokens': [400,
#     5707,
#     13500,
#     307,
#     7103,
#     294,
#     264,
#     6343,
#     917,
#     31493,
#     11,
#     293,
#     286,
#     393,
#     380,
#     1699,
#     337,
#     264],
#    'temperature': 0.0,
#    'avg_logprob': -0.14848303968888998,
#    'compression_ratio': 1.627906976744186,
#    'no_speech_prob': 0.00010218867100775242},
#   {'id': 94,
#    'seek': 30316,
#    'start': 323.68,
#    'end': 326.0,
#    'text': ' M2 Ultra here.',
#    'tokens': [376, 17, 20925, 510, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14848303968888998,
#    'compression_ratio': 1.627906976744186,
#    'no_speech_prob': 0.00010218867100775242},
#   {'id': 95,
#    'seek': 30316,
#    'start': 326.0,
#    'end': 330.64000000000004,
#    'text': ' But yeah, the Mac Mini now slots in really nicely underneath all of that.',
#    'tokens': [583,
#     1338,
#     11,
#     264,
#     5707,
#     18239,
#     586,
#     24266,
#     294,
#     534,
#     9594,
#     7223,
#     439,
#     295,
#     300,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.14848303968888998,
#    'compression_ratio': 1.627906976744186,
#    'no_speech_prob': 0.00010218867100775242},
#   {'id': 96,
#    'seek': 33064,
#    'start': 330.64,
#    'end': 334.64,
#    'text': " And of course, with the modularity of a desktop that doesn't come with a monitor built-in,",
#    'tokens': [400,
#     295,
#     1164,
#     11,
#     365,
#     264,
#     31111,
#     507,
#     295,
#     257,
#     14502,
#     300,
#     1177,
#     380,
#     808,
#     365,
#     257,
#     6002,
#     3094,
#     12,
#     259,
#     11],
#    'temperature': 0.0,
#    'avg_logprob': -0.1372808936898035,
#    'compression_ratio': 1.6601941747572815,
#    'no_speech_prob': 2.0649204088840634e-05},
#   {'id': 97,
#    'seek': 33064,
#    'start': 334.64,
#    'end': 338.44,
#    'text': ' now you pick whatever display you want with the $700 you save.',
#    'tokens': [586,
#     291,
#     1888,
#     2035,
#     4674,
#     291,
#     528,
#     365,
#     264,
#     1848,
#     18197,
#     291,
#     3155,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1372808936898035,
#    'compression_ratio': 1.6601941747572815,
#    'no_speech_prob': 2.0649204088840634e-05},
#   {'id': 98,
#    'seek': 33064,
#    'start': 338.44,
#    'end': 339.44,
#    'text': " It's funny.",
#    'tokens': [467, 311, 4074, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1372808936898035,
#    'compression_ratio': 1.6601941747572815,
#    'no_speech_prob': 2.0649204088840634e-05},
#   {'id': 99,
#    'seek': 33064,
#    'start': 339.44,
#    'end': 342.71999999999997,
#    'text': " In recent reviews, I've been trying to give sustainability notes where it's relevant.",
#    'tokens': [682,
#     5162,
#     10229,
#     11,
#     286,
#     600,
#     668,
#     1382,
#     281,
#     976,
#     16360,
#     5570,
#     689,
#     309,
#     311,
#     7340,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1372808936898035,
#    'compression_ratio': 1.6601941747572815,
#    'no_speech_prob': 2.0649204088840634e-05},
#   {'id': 100,
#    'seek': 33064,
#    'start': 342.71999999999997,
#    'end': 347.24,
#    'text': ' And so there are some neat ones with this machine like recycled aluminum, the packaging',
#    'tokens': [400,
#     370,
#     456,
#     366,
#     512,
#     10654,
#     2306,
#     365,
#     341,
#     3479,
#     411,
#     30674,
#     15656,
#     11,
#     264,
#     16836],
#    'temperature': 0.0,
#    'avg_logprob': -0.1372808936898035,
#    'compression_ratio': 1.6601941747572815,
#    'no_speech_prob': 2.0649204088840634e-05},
#   {'id': 101,
#    'seek': 33064,
#    'start': 347.24,
#    'end': 350.88,
#    'text': ' on the outside, the recycled plastics on the inside of the Mac.',
#    'tokens': [322,
#     264,
#     2380,
#     11,
#     264,
#     30674,
#     34356,
#     322,
#     264,
#     1854,
#     295,
#     264,
#     5707,
#     13],
#    'temperature': 0.0,
# ...
#    'start': 453.28,
#    'end': 456.28,
#    'text': " That's typically $100 off and I think with these machines it's $100.",
#    'tokens': [663,
#     311,
#     5850,
#     1848,
#     6879,
#     766,
#     293,
#     286,
#     519,
#     365,
#     613,
#     8379,
#     309,
#     311,
#     1848,
#     6879,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15805133289059267,
#    'compression_ratio': 1.680722891566265,
#    'no_speech_prob': 0.0002034280332736671},
#   {'id': 133,
#    'seek': 43632,
#    'start': 456.28,
#    'end': 458.36,
#    'text': ' So now that brings this down 100.',
#    'tokens': [407, 586, 300, 5607, 341, 760, 2319, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15805133289059267,
#    'compression_ratio': 1.680722891566265,
#    'no_speech_prob': 0.0002034280332736671},
#   {'id': 134,
#    'seek': 43632,
#    'start': 458.36,
#    'end': 462.88,
#    'text': ' That also brings the base M2 down to $499, which is great.',
#    'tokens': [663,
#     611,
#     5607,
#     264,
#     3096,
#     376,
#     17,
#     760,
#     281,
#     1848,
#     19,
#     8494,
#     11,
#     597,
#     307,
#     869,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15805133289059267,
#    'compression_ratio': 1.680722891566265,
#    'no_speech_prob': 0.0002034280332736671},
#   {'id': 135,
#    'seek': 46288,
#    'start': 462.88,
#    'end': 467.56,
#    'text': " So in conclusion, if you're trying to pick one Mac to buy right now, think of it this",
#    'tokens': [407,
#     294,
#     10063,
#     11,
#     498,
#     291,
#     434,
#     1382,
#     281,
#     1888,
#     472,
#     5707,
#     281,
#     2256,
#     558,
#     586,
#     11,
#     519,
#     295,
#     309,
#     341],
#    'temperature': 0.0,
#    'avg_logprob': -0.1357689693056304,
#    'compression_ratio': 1.726384364820847,
#    'no_speech_prob': 8.442643593298271e-05},
#   {'id': 136,
#    'seek': 46288,
#    'start': 467.56,
#    'end': 468.56,
#    'text': ' way.',
#    'tokens': [636, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1357689693056304,
#    'compression_ratio': 1.726384364820847,
#    'no_speech_prob': 8.442643593298271e-05},
#   {'id': 137,
#    'seek': 46288,
#    'start': 468.56,
#    'end': 474.68,
#    'text': " If you already have an Apple Silicon Mac, like an M1 generation Mac, you're good.",
#    'tokens': [759,
#     291,
#     1217,
#     362,
#     364,
#     6373,
#     25351,
#     5707,
#     11,
#     411,
#     364,
#     376,
#     16,
#     5125,
#     5707,
#     11,
#     291,
#     434,
#     665,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1357689693056304,
#    'compression_ratio': 1.726384364820847,
#    'no_speech_prob': 8.442643593298271e-05},
#   {'id': 138,
#    'seek': 46288,
#    'start': 474.68,
#    'end': 476.32,
#    'text': " You don't have to buy a new Mac every year.",
#    'tokens': [509, 500, 380, 362, 281, 2256, 257, 777, 5707, 633, 1064, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1357689693056304,
#    'compression_ratio': 1.726384364820847,
#    'no_speech_prob': 8.442643593298271e-05},
#   {'id': 139,
#    'seek': 46288,
#    'start': 476.32,
#    'end': 478.71999999999997,
#    'text': ' Those machines were a great update over the Intel ones.',
#    'tokens': [3950, 8379, 645, 257, 869, 5623, 670, 264, 19762, 2306, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1357689693056304,
#    'compression_ratio': 1.726384364820847,
#    'no_speech_prob': 8.442643593298271e-05},
#   {'id': 140,
#    'seek': 46288,
#    'start': 478.71999999999997,
#    'end': 479.71999999999997,
#    'text': " You're set.",
#    'tokens': [509, 434, 992, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1357689693056304,
#    'compression_ratio': 1.726384364820847,
#    'no_speech_prob': 8.442643593298271e-05},
#   {'id': 141,
#    'seek': 46288,
#    'start': 479.71999999999997,
#    'end': 482.12,
#    'text': " Now if you have an older machine and you're actually looking to upgrade, I would actually",
#    'tokens': [823,
#     498,
#     291,
#     362,
#     364,
#     4906,
#     3479,
#     293,
#     291,
#     434,
#     767,
#     1237,
#     281,
#     11484,
#     11,
#     286,
#     576,
#     767],
#    'temperature': 0.0,
#    'avg_logprob': -0.1357689693056304,
#    'compression_ratio': 1.726384364820847,
#    'no_speech_prob': 8.442643593298271e-05},
#   {'id': 142,
#    'seek': 46288,
#    'start': 482.12,
#    'end': 487.76,
#    'text': ' default to the Mac Mini and just start with the base M2 599 Mac Mini.',
#    'tokens': [7576,
#     281,
#     264,
#     5707,
#     18239,
#     293,
#     445,
#     722,
#     365,
#     264,
#     3096,
#     376,
#     17,
#     1025,
#     8494,
#     5707,
#     18239,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.1357689693056304,
#    'compression_ratio': 1.726384364820847,
#    'no_speech_prob': 8.442643593298271e-05},
#   {'id': 143,
#    'seek': 46288,
#    'start': 487.76,
#    'end': 492.76,
#    'text': ' And I would not buy the iMac right now because if you look at the specs specifically,',
#    'tokens': [400,
#     286,
#     576,
#     406,
#     2256,
#     264,
#     741,
#     34355,
#     558,
#     586,
#     570,
#     498,
#     291,
#     574,
#     412,
#     264,
#     27911,
#     4682,
#     11],
#    'temperature': 0.0,
#    'avg_logprob': -0.1357689693056304,
#    'compression_ratio': 1.726384364820847,
#    'no_speech_prob': 8.442643593298271e-05},
#   {'id': 144,
#    'seek': 49276,
#    'start': 492.76,
#    'end': 498.12,
#    'text': " it's still M1 and it's $1299 for a non-removable 24-inch display.",
#    'tokens': [309,
#     311,
#     920,
#     376,
#     16,
#     293,
#     309,
#     311,
#     1848,
#     4762,
#     8494,
#     337,
#     257,
#     2107,
#     12,
#     2579,
#     5179,
#     712,
#     4022,
#     12,
#     12415,
#     4674,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13011184370661355,
#    'compression_ratio': 1.6115942028985508,
#    'no_speech_prob': 0.00010669544280972332},
#   {'id': 145,
#    'seek': 49276,
#    'start': 498.12,
#    'end': 501.84,
#    'text': ' I would just get the Mac Mini instead and get whatever $600 screen you want.',
#    'tokens': [286,
#     576,
#     445,
#     483,
#     264,
#     5707,
#     18239,
#     2602,
#     293,
#     483,
#     2035,
#     1848,
#     15707,
#     2568,
#     291,
#     528,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13011184370661355,
#    'compression_ratio': 1.6115942028985508,
#    'no_speech_prob': 0.00010669544280972332},
#   {'id': 146,
#    'seek': 49276,
#    'start': 501.84,
#    'end': 503.08,
#    'text': ' You can swap that out however.',
#    'tokens': [509, 393, 18135, 300, 484, 4461, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13011184370661355,
#    'compression_ratio': 1.6115942028985508,
#    'no_speech_prob': 0.00010669544280972332},
#   {'id': 147,
#    'seek': 49276,
#    'start': 503.08,
#    'end': 505.28,
#    'text': " So I wouldn't recommend iMac right now.",
#    'tokens': [407, 286, 2759, 380, 2748, 741, 34355, 558, 586, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13011184370661355,
#    'compression_ratio': 1.6115942028985508,
#    'no_speech_prob': 0.00010669544280972332},
#   {'id': 148,
#    'seek': 49276,
#    'start': 505.28,
#    'end': 509.44,
#    'text': " And then if you know that you specifically want to be computing on the go, that's when",
#    'tokens': [400,
#     550,
#     498,
#     291,
#     458,
#     300,
#     291,
#     4682,
#     528,
#     281,
#     312,
#     15866,
#     322,
#     264,
#     352,
#     11,
#     300,
#     311,
#     562],
#    'temperature': 0.0,
#    'avg_logprob': -0.13011184370661355,
#    'compression_ratio': 1.6115942028985508,
#    'no_speech_prob': 0.00010669544280972332},
#   {'id': 149,
#    'seek': 49276,
#    'start': 509.44,
#    'end': 510.44,
#    'text': ' you move over.',
#    'tokens': [291, 1286, 670, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13011184370661355,
#    'compression_ratio': 1.6115942028985508,
#    'no_speech_prob': 0.00010669544280972332},
#   {'id': 150,
#    'seek': 49276,
#    'start': 510.44,
#    'end': 512.48,
#    'text': ' Okay, the laptops are really good.',
#    'tokens': [1033, 11, 264, 27642, 366, 534, 665, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13011184370661355,
#    'compression_ratio': 1.6115942028985508,
#    'no_speech_prob': 0.00010669544280972332},
#   {'id': 151,
#    'seek': 49276,
#    'start': 512.48,
#    'end': 515.4399999999999,
#    'text': ' You can get an M2 generation Macbook Pro.',
#    'tokens': [509, 393, 483, 364, 376, 17, 5125, 5707, 2939, 1705, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13011184370661355,
#    'compression_ratio': 1.6115942028985508,
#    'no_speech_prob': 0.00010669544280972332},
#   {'id': 152,
#    'seek': 49276,
#    'start': 515.4399999999999,
#    'end': 516.4399999999999,
#    'text': ' And those are excellent.',
#    'tokens': [400, 729, 366, 7103, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13011184370661355,
#    'compression_ratio': 1.6115942028985508,
#    'no_speech_prob': 0.00010669544280972332},
#   {'id': 153,
#    'seek': 49276,
#    'start': 516.4399999999999,
#    'end': 517.4399999999999,
#    'text': ' I just reviewed them.',
#    'tokens': [286, 445, 18429, 552, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13011184370661355,
#    'compression_ratio': 1.6115942028985508,
#    'no_speech_prob': 0.00010669544280972332},
#   {'id': 154,
#    'seek': 49276,
#    'start': 517.4399999999999,
#    'end': 519.56,
#    'text': ' If you want to check it out, links below the like button.',
#    'tokens': [759,
#     291,
#     528,
#     281,
#     1520,
#     309,
#     484,
#     11,
#     6123,
#     2507,
#     264,
#     411,
#     2960,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13011184370661355,
#    'compression_ratio': 1.6115942028985508,
#    'no_speech_prob': 0.00010669544280972332},
#   {'id': 155,
#    'seek': 49276,
#    'start': 519.56,
#    'end': 520.56,
#    'text': ' That video is up.',
#    'tokens': [663, 960, 307, 493, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13011184370661355,
#    'compression_ratio': 1.6115942028985508,
#    'no_speech_prob': 0.00010669544280972332},
#   {'id': 156,
#    'seek': 49276,
#    'start': 520.56,
#    'end': 522.16,
#    'text': " And that's how I think about the lineup.",
#    'tokens': [400, 300, 311, 577, 286, 519, 466, 264, 26461, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.13011184370661355,
#    'compression_ratio': 1.6115942028985508,
#    'no_speech_prob': 0.00010669544280972332},
#   {'id': 157,
#    'seek': 52216,
#    'start': 522.16,
#    'end': 526.8,
#    'text': " And honestly, if you can find an M1 generation Macbook Pro right now on a discount, that's",
#    'tokens': [400,
#     6095,
#     11,
#     498,
#     291,
#     393,
#     915,
#     364,
#     376,
#     16,
#     5125,
#     5707,
#     2939,
#     1705,
#     558,
#     586,
#     322,
#     257,
#     11635,
#     11,
#     300,
#     311],
#    'temperature': 0.0,
#    'avg_logprob': -0.15022713029888315,
#    'compression_ratio': 1.5714285714285714,
#    'no_speech_prob': 0.0002607903443276882},
#   {'id': 158,
#    'seek': 52216,
#    'start': 526.8,
#    'end': 527.8,
#    'text': ' really good too.',
#    'tokens': [534, 665, 886, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15022713029888315,
#    'compression_ratio': 1.5714285714285714,
#    'no_speech_prob': 0.0002607903443276882},
#   {'id': 159,
#    'seek': 52216,
#    'start': 527.8,
#    'end': 531.04,
#    'text': ' And then within each lineup, of course, I keep saying this, but the big difference between',
#    'tokens': [400,
#     550,
#     1951,
#     1184,
#     26461,
#     11,
#     295,
#     1164,
#     11,
#     286,
#     1066,
#     1566,
#     341,
#     11,
#     457,
#     264,
#     955,
#     2649,
#     1296],
#    'temperature': 0.0,
#    'avg_logprob': -0.15022713029888315,
#    'compression_ratio': 1.5714285714285714,
#    'no_speech_prob': 0.0002607903443276882},
#   {'id': 160,
#    'seek': 52216,
#    'start': 531.04,
#    'end': 537.24,
#    'text': ' M2, M2 Pro, M2 Max, and eventually M2 Ultra when it comes out is GPU.',
#    'tokens': [376,
#     17,
#     11,
#     376,
#     17,
#     1705,
#     11,
#     376,
#     17,
#     7402,
#     11,
#     293,
#     4728,
#     376,
#     17,
#     20925,
#     562,
#     309,
#     1487,
#     484,
#     307,
#     18407,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15022713029888315,
#    'compression_ratio': 1.5714285714285714,
#    'no_speech_prob': 0.0002607903443276882},
#   {'id': 161,
#    'seek': 52216,
#    'start': 537.24,
#    'end': 541.28,
#    'text': " So it shouldn't be a shock that they're all sort of similar in CPU performance.",
#    'tokens': [407,
#     309,
#     4659,
#     380,
#     312,
#     257,
#     5588,
#     300,
#     436,
#     434,
#     439,
#     1333,
#     295,
#     2531,
#     294,
#     13199,
#     3389,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15022713029888315,
#    'compression_ratio': 1.5714285714285714,
#    'no_speech_prob': 0.0002607903443276882},
#   {'id': 162,
#    'seek': 52216,
#    'start': 541.28,
#    'end': 544.68,
#    'text': ' But if the applications that you use and you know your workflow will take advantage of',
#    'tokens': [583,
#     498,
#     264,
#     5821,
#     300,
#     291,
#     764,
#     293,
#     291,
#     458,
#     428,
#     20993,
#     486,
#     747,
#     5002,
#     295],
#    'temperature': 0.0,
#    'avg_logprob': -0.15022713029888315,
#    'compression_ratio': 1.5714285714285714,
#    'no_speech_prob': 0.0002607903443276882},
#   {'id': 163,
#    'seek': 52216,
#    'start': 544.68,
#    'end': 547.64,
#    'text': " GPU power, then that's when you bump that out.",
#    'tokens': [18407, 1347, 11, 550, 300, 311, 562, 291, 9961, 300, 484, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15022713029888315,
#    'compression_ratio': 1.5714285714285714,
#    'no_speech_prob': 0.0002607903443276882},
#   {'id': 164,
#    'seek': 52216,
#    'start': 547.64,
#    'end': 550.76,
#    'text': " Okay, yeah, that's pretty much it.",
#    'tokens': [1033, 11, 1338, 11, 300, 311, 1238, 709, 309, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.15022713029888315,
#    'compression_ratio': 1.5714285714285714,
#    'no_speech_prob': 0.0002607903443276882},
#   {'id': 165,
#    'seek': 55076,
#    'start': 550.76,
#    'end': 554.48,
#    'text': ' Maybe a little bit shocking, but yeah, price for performance.',
#    'tokens': [2704,
#     257,
#     707,
#     857,
#     18776,
#     11,
#     457,
#     1338,
#     11,
#     3218,
#     337,
#     3389,
#     13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2816089357648577,
#    'compression_ratio': 1.4463276836158192,
#    'no_speech_prob': 3.292939072707668e-05},
#   {'id': 166,
#    'seek': 55076,
#    'start': 554.48,
#    'end': 556.4,
#    'text': ' Mac mini, kind of a huge winner.',
#    'tokens': [5707, 8382, 11, 733, 295, 257, 2603, 8507, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2816089357648577,
#    'compression_ratio': 1.4463276836158192,
#    'no_speech_prob': 3.292939072707668e-05},
#   {'id': 167,
#    'seek': 55076,
#    'start': 556.4,
#    'end': 562.28,
#    'text': ' Mac mini might make me miss removable memory, but it makes most massive media machines',
#    'tokens': [5707,
#     8382,
#     1062,
#     652,
#     385,
#     1713,
#     44060,
#     4675,
#     11,
#     457,
#     309,
#     1669,
#     881,
#     5994,
#     3021,
#     8379],
#    'temperature': 0.0,
#    'avg_logprob': -0.2816089357648577,
#    'compression_ratio': 1.4463276836158192,
#    'no_speech_prob': 3.292939072707668e-05},
#   {'id': 168,
#    'seek': 55076,
#    'start': 562.28,
#    'end': 565.16,
#    'text': ' still pretty mid.',
#    'tokens': [920, 1238, 2062, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2816089357648577,
#    'compression_ratio': 1.4463276836158192,
#    'no_speech_prob': 3.292939072707668e-05},
#   {'id': 169,
#    'seek': 55076,
#    'start': 565.16,
#    'end': 566.16,
#    'text': ' Thanks for watching.',
#    'tokens': [2561, 337, 1976, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2816089357648577,
#    'compression_ratio': 1.4463276836158192,
#    'no_speech_prob': 3.292939072707668e-05},
#   {'id': 170,
#    'seek': 55076,
#    'start': 566.16,
#    'end': 567.68,
#    'text': ' Catch you guys the next one.',
#    'tokens': [23869, 291, 1074, 264, 958, 472, 13],
#    'temperature': 0.0,
#    'avg_logprob': -0.2816089357648577,
#    'compression_ratio': 1.4463276836158192,
#    'no_speech_prob': 3.292939072707668e-05},
#   {'id': 171,
#    'seek': 56768,
#    'start': 567.68,
#    'end': 581.1999999999999,
#    'text': ' Peace.',
#    'tokens': [50364, 13204, 13, 51040],
#    'temperature': 0.0,
#    'avg_logprob': -0.9097466468811035,
#    'compression_ratio': 0.42857142857142855,
#    'no_speech_prob': 0.0007279480923898518}],
#  'language': 'en'}

# %% [markdown]
# #### Preparing the transcripted text from the video for GPT-3 fine-tuning

# %%
from transformers import GPT2TokenizerFast

tokenizer = GPT2TokenizerFast.from_pretrained("gpt2")

def count_tokens(text: str) -> int:
    """count the number of tokens in a string"""
    return len(tokenizer.encode(text))

video = 'MKBHD Apple Video'
res = []
segments = output['segments']
for segment in segments:
    res.append(('MKBHD Apple Video', segment['id'], segment['text'], count_tokens(segment['text'])))

df = pd.DataFrame(res, columns=["title", "heading", "content", "tokens"])
df.sample(10)
# Out:
#                  title  heading  \
# 159  MKBHD Apple Video      159
# 116  MKBHD Apple Video      116
# 74   MKBHD Apple Video       74
# 109  MKBHD Apple Video      109
# 24   MKBHD Apple Video       24
# 76   MKBHD Apple Video       76
# 19   MKBHD Apple Video       19
# 8    MKBHD Apple Video        8
# 25   MKBHD Apple Video       25
# 90   MKBHD Apple Video       90
#
#                                                content  tokens
# 159   And then within each lineup, of course, I kee...      19
# 116   fledgling creator with not a lot of space and...      17
# 74             on a chip starts at 1990, 99 right now.      11
# 109                        that I did back in college.       7
# 24    And when the Mac Mini moved to Apple Silicon ...      18
# 76    And that's the real reason I'm calling these ...      22
# 19    It's basically the laptop, but without the sc...      14
# 8     So I said in my last video about the MacBook ...      19
# 25                   hilarious leap up in performance.       6
# 90    It's just been sitting with the unupgraded M1...      21

# %% [markdown]
# #### Computing the segments of the transcript & specific query embeddings

# %%
EMBEDDING_MODEL = "text-embedding-ada-002"
openai.api_key = 'x'

# %% [markdown]
# Function explanation:
#
# compute_doc_embeddings(): Create an embedding for each row in the dataframe using the OpenAI Embeddings API. Return a dictionary that maps between each embedding vector and the index of the row that it corresponds to.

# %%
def get_embedding(text: str, model: str=EMBEDDING_MODEL) -> list[float]:
    result = openai.Embedding.create(
      model=model,
      input=text
    )
    return result["data"][0]["embedding"]

def compute_doc_embeddings(df: pd.DataFrame) -> dict[tuple[str, str], list[float]]:
    return {
        idx: get_embedding(r.content) for idx, r in df.iterrows()
    }

video_embeddings = compute_doc_embeddings(df)

# %%
# An example embedding:
example_entry = list(video_embeddings.items())[0]
print(f"{example_entry[0]} : {example_entry[1][:5]}... ({len(example_entry[1])} entries)")
# Out:
# 0 : [-0.01549014076590538, 0.005196060054004192, 0.013921518810093403, -0.039137113839387894, -0.0023480309173464775]... (1536 entries)

# %% [markdown]
# #### Finding the most similar segment of the video embeddings to the question embedding

# %% [markdown]
# vector_similarity(): Returns the similarity between two vectors. Because OpenAI Embeddings are normalized to length 1, the cosine similarity is the same as the dot product.
#
# order_document_sections_by_query_similarity(): Find the query embedding for the supplied query, and compare it against all of the pre-calculated document embeddings to find the most relevant sections. Return the list of document sections, sorted by relevance in descending order.

# %%
def vector_similarity(x: list[float], y: list[float]) -> float:
    
    return np.dot(np.array(x), np.array(y))

def order_document_sections_by_query_similarity(query: str, contexts: dict[(str, str), np.array]) -> list[(float, (str, str))]:
    
    query_embedding = get_embedding(query)
    
    document_similarities = sorted([
        (vector_similarity(query_embedding, doc_embedding), doc_index) for doc_index, doc_embedding in contexts.items()
    ], reverse=True)
    
    return document_similarities

# %%
order_document_sections_by_query_similarity("What is the Mac Mini?", video_embeddings)[:5]
# Out:
# [(0.8532579990130094, 142),
#  (0.8488487976721378, 80),
#  (0.8476153252892457, 166),
#  (0.8438641904334057, 37),
#  (0.8193416718459371, 95)]

# %% [markdown]
# #### Construct a proper query prompt to answer a specific question

# %%
MAX_SECTION_LEN = 500
SEPARATOR = "\n* "
ENCODING = "gpt2"  # encoding for text-davinci-003

encoding = tiktoken.get_encoding(ENCODING)
separator_len = len(encoding.encode(SEPARATOR))

f"Context separator contains {separator_len} tokens"
# Out:
# 'Context separator contains 3 tokens'

# %%
def construct_prompt(question: str, context_embeddings: dict, df: pd.DataFrame) -> str:
    
    most_relevant_document_sections = order_document_sections_by_query_similarity(question, context_embeddings)
    
    chosen_sections = []
    chosen_sections_len = 0
    chosen_sections_indexes = []
     
    for _, section_index in most_relevant_document_sections:
        # Add contexts until we run out of space.        
        document_section = df.loc[section_index]
        
        chosen_sections_len += document_section.tokens + separator_len
        if chosen_sections_len > MAX_SECTION_LEN:
            break
            
        chosen_sections.append(SEPARATOR + document_section.content.replace("\n", " "))
        chosen_sections_indexes.append(str(section_index))
            
    # Useful diagnostic information
    print(f"Selected {len(chosen_sections)} video sections from database:")
    print("\n".join(chosen_sections_indexes))
    
    header = """Answer the question as truthfully as possible using the provided context, and if the answer is not contained within the text below, say "I don't know."\n\nContext:\n"""
    
    return header + "".join(chosen_sections) + "\n\n Q: " + question + "\n A:"

# %%
prompt = construct_prompt(
    "What is the Mac Mini?",
    video_embeddings,
    df
)

print("===\n", prompt)
# Out:
# Selected 26 document sections:
# 142
# 80
# 166
# 37
# 95
# 167
# 113
# 29
# 55
# 118
# 145
# 89
# 2
# 13
# 108
# 19
# 88
# 151
# 101
# 138
# 21
# 137
# 12
# 52
# 18
# 9
# ===
#  Answer the question as truthfully as possible using the provided context, and if the answer is not contained within the text below, say "I don't know."
#
# Context:
#
# *  default to the Mac Mini and just start with the base M2 599 Mac Mini.
# *  And then here's the Mac Minis, which is the same performance, but for less money.
# *  Mac mini, kind of a huge winner.
# *  And so then we also have the M2 Pro Mac Mini.
# *  But yeah, the Mac Mini now slots in really nicely underneath all of that.
# *  Mac mini might make me miss removable memory, but it makes most massive media machines
# *  capable, tiny machine for a college dorm room where space is at a premium.
# *  So this M1 Mac Mini is already dramatically better than the Intel one for 99% of people.
# *  And on top of that, the thermal advantage potentially of a Mac Mini with active cooling
# *  I had spent in total with the Mac and all the upgrades $1,759 for the fastest Mac Mini
# *  I would just get the Mac Mini instead and get whatever $600 screen you want.
# *  Like even right now, it kind of feels like Apple low key forgot about the iMac.
# *  than a base Mac Pro right now, more CPU power anyway.
# *  So first the M2 version, the base M2 Mac Mini is a game changer because it's all the benefits
# *  I haven't done a video on the Mac Mini since the fastest Mac Mini in the world project
# *  It's basically the laptop, but without the screen and the keyboard.
# *  And for being honest, the iMac is cool, but it's not for everyone.
# *  You can get an M2 generation Macbook Pro.
# *  on the outside, the recycled plastics on the inside of the Mac.
# *  You don't have to buy a new Mac every year.
# *  a small exhaust vent for active cooling and a headphone jack.
# *  If you already have an Apple Silicon Mac, like an M1 generation Mac, you're good.
# *  and an M2 Pro option, both of which are kind of game changers in their own ways.
# *  the M1 Pro and the M1 Max in the CPU department that was in the highest end MacBook Pros before.
# *  computer in there.
# *  interesting machine.
#
#  Q: What is the Mac Mini?
#  A:

# %% [markdown]
# #### Answer the user's question based on the specific context

# %%
COMPLETIONS_MODEL = "text-davinci-003"

# %%
COMPLETIONS_API_PARAMS = {
    # We use temperature of 0.0 because it gives the most predictable, factual answer.
    "temperature": 1.0,
    "max_tokens": 300,
    "model": COMPLETIONS_MODEL,
}

# %%
def answer_query_with_context(
    query: str,
    df: pd.DataFrame,
    document_embeddings: dict[(str, str), np.array],
    show_prompt: bool = False
) -> str:
    prompt = construct_prompt(
        query,
        document_embeddings,
        df
    )
    
    if show_prompt:
        print(prompt)

    response = openai.Completion.create(
                prompt=prompt,
                **COMPLETIONS_API_PARAMS
            )

    return response["choices"][0]["text"].strip(" \n")

# %%
answer_query_with_context("What is the Mac Mini?", df, video_embeddings)
# Out:
# Selected 26 document sections:
# 142
# 80
# 166
# 37
# 95
# 167
# 113
# 29
# 55
# 118
# 145
# 89
# 2
# 13
# 108
# 19
# 88
# 151
# 101
# 138
# 21
# 137
# 12
# 52
# 18
# 9
# 'The Mac Mini is a small, capable computer with active cooling and a headphone jack. It has an M2 599 base version and an M2 Pro option, making it a game changer in its own ways. It is capable of massive media machines and is a great option for college dorm rooms where space is at a premium.'

# %% [markdown]
# #### Let's test some examples

# %%
query = "What is the price of the Mac Mini?"
answer = answer_query_with_context(query, df, video_embeddings)

print(f"\nQ: {query}\nA: {answer}")
# Out:
# Selected 26 document sections:
# 142
# 118
# 80
# 145
# 37
# 166
# 29
# 15
# 32
# 2
# 89
# 55
# 151
# 95
# 79
# 134
# 138
# 35
# 144
# 167
# 113
# 72
# 7
# 132
# 13
# 108
#
# Q: What is the price of the Mac Mini?
# A: The price of the Mac Mini starts at $599.

# %%
query = "What might be controversial about Apple?"
answer = answer_query_with_context(query, df, video_embeddings)

print(f"\nQ: {query}\nA: {answer}")
# Out:
# Selected 31 document sections:
# 89
# 23
# 88
# 4
# 69
# 138
# 12
# 79
# 166
# 2
# 101
# 137
# 87
# 167
# 165
# 147
# 151
# 55
# 52
# 104
# 171
# 29
# 82
# 139
# 124
# 135
# 9
# 102
# 80
# 18
# 106
#
# Q: What might be controversial about Apple?
# A: Apple's prioritization of laptops over desktops might be seen as controversial, as it has resulted in many of the desktop options not being upgraded for a long time.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
